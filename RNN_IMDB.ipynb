# %%
import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import re
from collections import Counter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-bc198fd1f888> in <module>
# ----> 1 import torch
#       2 from torch import nn
#       3 from torch import optim
#       4 from torch.utils.data import DataLoader, TensorDataset
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# <font color=red>Load data</font>

# %%
df_train = pd.read_csv('data/IMDB_train.csv')

# %%
df_train.head()
# Out:
#                                               review sentiment
# 0  In 1954 Marlon Brando was THE hot actor after ...  positive
# 1  It was very heart-warming. As an expatriated f...  positive
# 2  "Cinderella" is one of the most beloved of all...  positive
# 3  "I fear you speak upon the rack, where men enf...  positive
# 4  I loved it! Fred MacMurray is wonderful as Ski...  positive

# %% [markdown]
# <font color=red> Convert words in sentence to lower case and
# remove non-word characters</font>

# %%
def preprocess_sentence(s):
    # convert to lower
    s = s.lower()
    # remove all non-word characters (everything except numbers and letters)
    s = re.sub(r"[^\w\s]", '', s)
    return s

# %% [markdown]
# <font color=red> Determine the vocabulary size </font>

# %%
def get_vocabulary_size(reviews):
    reviews = [preprocess_sentence(s) for s in reviews]
    combined_reviews = ' '.join(reviews)
    words = combined_reviews.split()
    count_words = Counter(words)
    total_words = len(words)
    sorted_words = count_words.most_common(total_words)
    return len(sorted_words), sorted_words

# %%
vocab_dim, sorted_words = get_vocabulary_size(df_train['review'].tolist())

# %%
vocab_dim
# Out:
# 153720

# %% [markdown]
# <font color=red> Word to integer </font>

# %%
word2int = {w: i+1 for i, (w, c) in enumerate(sorted_words)}

# %%
list(word2int.items())[:5]
# Out:
# [('the', 1), ('and', 2), ('a', 3), ('of', 4), ('to', 5)]

# %% [markdown]
# <font color=red> Tokenize the sentence (review)</font>

# %%
def tokenize(reviews):
    int_reviews = []
    for review in reviews:
        review = preprocess_sentence(review)
        r = [word2int[w] for w in review.split()]
        int_reviews.append(r)
    return int_reviews

# %%
int_reviews = tokenize(df_train['review'].tolist())

# %%
# int_reviews[:1]

# %% [markdown]
# <font color=red> Padding sentence by adding 0 at the end to reach the maximum lenght
# or truncating the sentence to meet the maxium length</font>

# %%
def padding_review(int_reviews, maximum_length=200):
    padded_reviews = np.zeros((len(int_reviews), maximum_length), dtype=int)
    for i, int_review in enumerate(int_reviews):
        review_len = len(int_review)
        if review_len >= maximum_length:
            padded_reviews[i, :] = np.array(int_review[:maximum_length])
        else:
            _temp = int_review + list(np.zeros(maximum_length-review_len))
            padded_reviews[i, :] = np.array(_temp)
    return padded_reviews

# %%
maximum_length=200
padded_reviews = padding_review(int_reviews, maximum_length)
vocab_dim = vocab_dim + 1 # +1 for padding 0

# %% [markdown]
# <font color=red> Encode labels: 1-> positive, 0->negative</font>

# %%
int_labels = [1 if label == 'positive' else 0 
              for label in df_train['sentiment'].tolist()
             ]
int_labels = np.array(int_labels)

# %% [markdown]
# <font color=red> Loading data and batching </font>

# %%
train_data = TensorDataset(torch.from_numpy(padded_reviews),
                          torch.from_numpy(np.array(int_labels)))
train_loader = DataLoader(train_data, shuffle=True, batch_size=128)

# %% [markdown]
# <font color=red> Use GPU or CPU</font>

# %%
# CUDA for pytorch
use_cuda = torch.cuda.is_available() # return True if pc has a GPU
#use_cuda = False
device = torch.device("cuda:0" if use_cuda else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# <font color=red> Define a RNN model </font>

# %%
class SentimentLSTM(nn.Module):
    def __init__(self, vocab_dim, output_dim, embedding_dim,
                 hidden_dim, n_layers, dropout_rate):
        super().__init__()
        self.n_layers = n_layers
        self.hidden_dim = hidden_dim

        # embbeding layer
        # Ref: https://pytorch.org/tutorials/beginner/nlp/word_embeddings_tutorial.html
        self.embedding = nn.Embedding(vocab_dim, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, n_layers,
                           dropout=dropout_rate, batch_first=True)
         # dropout layer
        self.dropout = nn.Dropout(0.5)
        # fully connected layer
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.sigmoid = nn.Sigmoid()
    
    def forward(self, x):
        batch_size = x.size(0)
        
        #embbeding:
        embed = self.embedding(x)
        # initialized hidden state and cell state
        hidden = (torch.zeros(self.n_layers, batch_size, self.hidden_dim).to(device),
                  torch.zeros(self.n_layers, batch_size, self.hidden_dim).to(device)) 
        # lSTM
        out, hidden = self.lstm(embed, hidden)
        
        # reshape output size
        out = out.contiguous().view(-1, self.hidden_dim)
        # dropout
        out = self.dropout(out)
        # fully connected layer
        out = self.fc(out)
        # sigmoid
        out = self.sigmoid(out)
        # reshape to get batch_first=True
        out = out.view(batch_size, -1)
        # for Sentiment model, the final output is the output
        #  of the last timestep
        out = out[:, -1]
        
        return out, hidden

# %% [markdown]
# <font color=red> Train model </font>

# %%
output_dim = 1 # positve/negative labels
embedding_dim = 400
hidden_dim = 512
n_layers = 2
model = SentimentLSTM(vocab_dim, output_dim, embedding_dim,
                     hidden_dim, n_layers, 0.5)
model = model.to(device)
loss_function = nn.BCELoss() # BCELoss for binay class instead of using CrossEntropy
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
n_epochs = 3

counter = 0
print_every = 100
for epoch in range(n_epochs):
    for inputs, labels in train_loader:
        counter += 1
        labels = labels.to(device)        
        inputs = inputs.type(torch.LongTensor)
        inputs =  inputs.to(device)
        optimizer.zero_grad()
        output, hidden = model(inputs)
        loss = loss_function(output, labels.float())
        
        loss.backward() # Does backpropagation and calculates gradients
        optimizer.step() # Updates the weights accordingly
        if counter % print_every == 0:
            print(f'Epoch = {epoch+1}/{n_epochs} ....',
                 f'Step = {counter} ....',
                 f'Binary Loss = {loss.item():.4f}')
# Out:
# Epoch = 1/3 .... Step = 100 .... Binary Loss = 0.6943
# Epoch = 1/3 .... Step = 200 .... Binary Loss = 0.6909
# Epoch = 2/3 .... Step = 300 .... Binary Loss = 0.6742
# Epoch = 2/3 .... Step = 400 .... Binary Loss = 0.6761
# Epoch = 2/3 .... Step = 500 .... Binary Loss = 0.6618
# Epoch = 3/3 .... Step = 600 .... Binary Loss = 0.5488
# Epoch = 3/3 .... Step = 700 .... Binary Loss = 0.4722
# Epoch = 3/3 .... Step = 800 .... Binary Loss = 0.4125

# %%
def predict(model, reviews, labels):
    #Tokenize (enocode the reviews)
    correct = 0
    total = 0
    index = 0
    
    _reviews = [preprocess_sentence(s) for s in reviews]
    int_reviews = tokenize(reviews)    
    padded_reviews = padding_review(int_reviews, maximum_length)    
    padded_reviews = torch.from_numpy(padded_reviews)
    padded_reviews = padded_reviews.type(torch.LongTensor)
    padded_reviews = padded_reviews.to(device)
    with torch.no_grad():
        output, hidden = model(padded_reviews)
    for i, o in enumerate(output):
        if o.item() >=0.5:
            if labels[index] == 1:
                correct += 1
                print("Correct")
            total += 1
            index += 1
            #print(f'{reviews[i]}')
            print(f'Positive with probability = {o.item():.3f}')
        else:
            if labels[index] == 0:
                correct += 1
                print("Correct")
            total += 1
            index += 1
            #print(f'{reviews[i]}') 
            print(f'Negative with probability = {o.item():.3f}')
    accuracy = correct / total
    print("Accuracy:", accuracy)

# %%
# fix random seed for reproducible
torch.manual_seed(2021)

df_test = pd.read_csv('data/IMDB_test.csv')

# converting to list
review_list = df_test['review'].tolist()
  
review_list = review_list[:600]

vocab_dim, sorted_words = get_vocabulary_size(df_test['review'].tolist())

word2int = {w: i+1 for i, (w, c) in enumerate(sorted_words)}

int_labels = [1 if label == 'positive' else 0 
              for label in df_test['sentiment'].tolist()
             ]

int_labels = int_labels[:600]

predict(model, review_list, int_labels)
# Out:
# Positive with probability = 0.646
# Correct
# Positive with probability = 0.668
# Negative with probability = 0.441
# Correct
# Negative with probability = 0.491
# Correct
# Positive with probability = 0.640
# Correct
# Negative with probability = 0.161
# Correct
# Negative with probability = 0.148
# Positive with probability = 0.903
# Positive with probability = 0.792
# Correct
# Negative with probability = 0.306
# Negative with probability = 0.257
# Negative with probability = 0.374
# Correct
# Negative with probability = 0.334
# Positive with probability = 0.593
# Negative with probability = 0.100
# Positive with probability = 0.702
# Correct
# Negative with probability = 0.074
# Correct
# Negative with probability = 0.253
# Correct
# Positive with probability = 0.892
# Correct
# Positive with probability = 0.946
# Positive with probability = 0.837
# Correct
# Positive with probability = 0.848
# Correct
# Positive with probability = 0.892
# Correct
# Positive with probability = 0.646
# Positive with probability = 0.951
# Correct
# Negative with probability = 0.452
# Positive with probability = 0.925
# Negative with probability = 0.072
# Correct
# Positive with probability = 0.968
# Negative with probability = 0.482
# Correct
# Negative with probability = 0.315
# Correct
# Positive with probability = 0.705
# Positive with probability = 0.877
# Correct
# Negative with probability = 0.232
# Positive with probability = 0.952
# Correct
# Positive with probability = 0.905
# Correct
# Positive with probability = 0.585
# Positive with probability = 0.565
# Positive with probability = 0.909
# Correct
# Positive with probability = 0.918
# Correct
# Negative with probability = 0.340
# Negative with probability = 0.465
# Correct
# Negative with probability = 0.117
# Negative with probability = 0.463
# Positive with probability = 0.533
# Negative with probability = 0.363
# Positive with probability = 0.757
# Correct
# Negative with probability = 0.320
# Negative with probability = 0.285
# Correct
# Positive with probability = 0.945
# Correct
# Negative with probability = 0.205
# Correct
# Positive with probability = 0.957
# Correct
# Negative with probability = 0.353
# Correct
# Positive with probability = 0.531
# Negative with probability = 0.420
# Negative with probability = 0.423
# Correct
# Negative with probability = 0.101
# Correct
# Negative with probability = 0.184
# Negative with probability = 0.428
# Correct
# Negative with probability = 0.097
# Positive with probability = 0.947
# Correct
# Negative with probability = 0.128
# Correct
# Positive with probability = 0.624
# Correct
# Positive with probability = 0.878
# Positive with probability = 0.690
# Correct
# Negative with probability = 0.175
# Negative with probability = 0.185
# Positive with probability = 0.738
# Correct
# Negative with probability = 0.271
# Positive with probability = 0.902
# Negative with probability = 0.061
# Correct
# Negative with probability = 0.496
# Correct
# Negative with probability = 0.317
# Negative with probability = 0.338
# Correct
# Positive with probability = 0.836
# Correct
# Negative with probability = 0.144
# Correct
# Negative with probability = 0.405
# Correct
# Positive with probability = 0.938
# Negative with probability = 0.445
# Correct
# Positive with probability = 0.540
# Correct
# Negative with probability = 0.259
# Negative with probability = 0.296
# Correct
# Positive with probability = 0.559
# Correct
# Negative with probability = 0.197
# Correct
# Positive with probability = 0.695
# Positive with probability = 0.735
# Negative with probability = 0.316
# Positive with probability = 0.954
# Negative with probability = 0.431
# Positive with probability = 0.536
# Correct
# Positive with probability = 0.779
# Negative with probability = 0.497
# Correct
# Negative with probability = 0.137
# Correct
# Positive with probability = 0.886
# Correct
# Negative with probability = 0.364
# Correct
# Negative with probability = 0.205
# Correct
# Positive with probability = 0.921
# Correct
# Positive with probability = 0.515
# Negative with probability = 0.239
# Positive with probability = 0.874
# Correct
# Positive with probability = 0.781
# Correct
# Positive with probability = 0.907
# Correct
# Positive with probability = 0.558
# Correct
# Negative with probability = 0.293
# Correct
# Negative with probability = 0.134
# Negative with probability = 0.421
# Correct
# Positive with probability = 0.944
# Correct
# Positive with probability = 0.823
# Negative with probability = 0.181
# Negative with probability = 0.302
# Correct
# Positive with probability = 0.928
# Correct
# Positive with probability = 0.708
# Correct
# Positive with probability = 0.598
# Positive with probability = 0.672
# Correct
# Positive with probability = 0.543
# Negative with probability = 0.444
# Correct
# Negative with probability = 0.110
# Correct
# Positive with probability = 0.635
# Positive with probability = 0.514
# Negative with probability = 0.453
# Correct
# Negative with probability = 0.161
# Correct
# Negative with probability = 0.315
# Correct
# Positive with probability = 0.626
# Correct
# Positive with probability = 0.793
# Correct
# Positive with probability = 0.567
# Correct
# Positive with probability = 0.634
# Negative with probability = 0.193
# Correct
# Negative with probability = 0.454
# Correct
# Negative with probability = 0.226
# Correct
# Negative with probability = 0.333
# Correct
# Positive with probability = 0.538
# Positive with probability = 0.953
# Correct
# Negative with probability = 0.421
# Negative with probability = 0.400
# Positive with probability = 0.772
# Correct
# Positive with probability = 0.623
# Positive with probability = 0.640
# Correct
# Negative with probability = 0.231
# Positive with probability = 0.889
# Correct
# Negative with probability = 0.417
# Negative with probability = 0.284
# Positive with probability = 0.551
# Negative with probability = 0.173
# Correct
# Negative with probability = 0.374
# Negative with probability = 0.293
# Correct
# Negative with probability = 0.203
# Positive with probability = 0.634
# Positive with probability = 0.539
# Positive with probability = 0.903
# Correct
# Negative with probability = 0.299
# Negative with probability = 0.206
# Negative with probability = 0.499
# Correct
# Negative with probability = 0.047
# Correct
# Positive with probability = 0.638
# Negative with probability = 0.027
# Positive with probability = 0.563
# Negative with probability = 0.389
# Correct
# Positive with probability = 0.736
# Positive with probability = 0.967
# Correct
# Positive with probability = 0.533
# Negative with probability = 0.473
# Correct
# Positive with probability = 0.794
# Positive with probability = 0.620
# Correct
# Positive with probability = 0.960
# Negative with probability = 0.418
# Correct
# Negative with probability = 0.257
# Correct
# Positive with probability = 0.885
# Positive with probability = 0.685
# Negative with probability = 0.259
# Positive with probability = 0.673
# Correct
# Positive with probability = 0.958
# Negative with probability = 0.485
# Correct
# Negative with probability = 0.434
# Correct
# Negative with probability = 0.117
# Correct
# Negative with probability = 0.449
# Negative with probability = 0.498
# Negative with probability = 0.475
# Positive with probability = 0.908
# Correct
# Negative with probability = 0.243
# Correct
# Negative with probability = 0.078
# Negative with probability = 0.212
# Correct
# Positive with probability = 0.826
# Negative with probability = 0.488
# Positive with probability = 0.659
# Negative with probability = 0.120
# Correct
# Negative with probability = 0.110
# Correct
# Positive with probability = 0.931
# Negative with probability = 0.175
# Correct
# Positive with probability = 0.744
# Negative with probability = 0.293
# Negative with probability = 0.370
# Correct
# Negative with probability = 0.350
# Correct
# Positive with probability = 0.901
# Correct
# Negative with probability = 0.399
# Correct
# Positive with probability = 0.630
# Correct
# Positive with probability = 0.689
# Correct
# Positive with probability = 0.779
# Negative with probability = 0.369
# Correct
# Negative with probability = 0.262
# Correct
# Negative with probability = 0.312
# Correct
# Positive with probability = 0.703
# Correct
# Positive with probability = 0.952
# Correct
# Positive with probability = 0.933
# Correct
# Positive with probability = 0.859
# Correct
# Positive with probability = 0.925
# Correct
# Positive with probability = 0.542
# Correct
# Positive with probability = 0.956
# Negative with probability = 0.333
# Positive with probability = 0.908
# Positive with probability = 0.555
# Correct
# Negative with probability = 0.282
# Correct
# Negative with probability = 0.295
# Positive with probability = 0.644
# Correct
# Positive with probability = 0.853
# Negative with probability = 0.384
# Correct
# Positive with probability = 0.963
# Correct
# Negative with probability = 0.418
# Correct
# Positive with probability = 0.866
# Correct
# Negative with probability = 0.295
# Negative with probability = 0.289
# Correct
# Negative with probability = 0.090
# Correct
# Positive with probability = 0.889
# Positive with probability = 0.778
# Correct
# Negative with probability = 0.136
# Positive with probability = 0.695
# Negative with probability = 0.187
# Correct
# Positive with probability = 0.538
# Negative with probability = 0.375
# Correct
# Negative with probability = 0.135
# Negative with probability = 0.490
# Positive with probability = 0.942
# Correct
# Positive with probability = 0.918
# Correct
# Positive with probability = 0.802
# Positive with probability = 0.790
# Correct
# Negative with probability = 0.220
# Correct
# Positive with probability = 0.969
# Correct
# Negative with probability = 0.475
# Negative with probability = 0.166
# Negative with probability = 0.179
# Positive with probability = 0.519
# Correct
# Positive with probability = 0.885
# Negative with probability = 0.423
# Negative with probability = 0.393
# Negative with probability = 0.475
# Negative with probability = 0.314
# Correct
# Negative with probability = 0.189
# Correct
# Positive with probability = 0.941
# Negative with probability = 0.164
# Negative with probability = 0.270
# Correct
# Positive with probability = 0.976
# Correct
# Positive with probability = 0.844
# Positive with probability = 0.679
# Negative with probability = 0.097
# Correct
# Negative with probability = 0.188
# Correct
# Positive with probability = 0.977
# Negative with probability = 0.177
# Correct
# Positive with probability = 0.954
# Correct
# Negative with probability = 0.153
# Correct
# Positive with probability = 0.868
# Correct
# Positive with probability = 0.616
# Negative with probability = 0.269
# Correct
# Negative with probability = 0.490
# Correct
# Negative with probability = 0.142
# Correct
# Positive with probability = 0.963
# Negative with probability = 0.180
# Positive with probability = 0.835
# Correct
# Positive with probability = 0.773
# Correct
# Negative with probability = 0.263
# Positive with probability = 0.935
# Correct
# Negative with probability = 0.245
# Negative with probability = 0.108
# Correct
# Negative with probability = 0.124
# Correct
# Positive with probability = 0.521
# Correct
# Negative with probability = 0.297
# Positive with probability = 0.888
# Negative with probability = 0.234
# Correct
# Negative with probability = 0.215
# Correct
# Negative with probability = 0.446
# Negative with probability = 0.327
# Correct
# Positive with probability = 0.849
# Correct
# Positive with probability = 0.778
# Positive with probability = 0.663
# Correct
# Negative with probability = 0.357
# Correct
# Negative with probability = 0.245
# Negative with probability = 0.127
# Correct
# Positive with probability = 0.585
# Correct
# Negative with probability = 0.455
# Correct
# Negative with probability = 0.155
# Correct
# Negative with probability = 0.130
# Correct
# Negative with probability = 0.333
# Correct
# Negative with probability = 0.278
# Correct
# Negative with probability = 0.187
# Correct
# Positive with probability = 0.561
# Positive with probability = 0.576
# Correct
# Negative with probability = 0.102
# Correct
# Negative with probability = 0.403
# Negative with probability = 0.461
# Correct
# Positive with probability = 0.772
# Correct
# Positive with probability = 0.567
# Negative with probability = 0.442
# Negative with probability = 0.493
# Positive with probability = 0.887
# Correct
# Negative with probability = 0.080
# Positive with probability = 0.624
# Correct
# Negative with probability = 0.481
# Correct
# Negative with probability = 0.394
# Correct
# Negative with probability = 0.074
# Negative with probability = 0.106
# Negative with probability = 0.263
# Positive with probability = 0.823
# Positive with probability = 0.563
# Correct
# Positive with probability = 0.694
# Positive with probability = 0.648
# Negative with probability = 0.155
# Positive with probability = 0.538
# Correct
# Positive with probability = 0.914
# Correct
# Negative with probability = 0.207
# Negative with probability = 0.283
# Negative with probability = 0.243
# Correct
# Positive with probability = 0.904
# Negative with probability = 0.341
# Positive with probability = 0.788
# Correct
# Negative with probability = 0.457
# Negative with probability = 0.295
# Negative with probability = 0.262
# Positive with probability = 0.629
# Correct
# Negative with probability = 0.248
# Correct
# Positive with probability = 0.560
# Correct
# Positive with probability = 0.635
# Correct
# Positive with probability = 0.970
# Correct
# Positive with probability = 0.907
# Positive with probability = 0.637
# Correct
# Positive with probability = 0.962
# Negative with probability = 0.491
# Negative with probability = 0.435
# Correct
# Negative with probability = 0.388
# Positive with probability = 0.965
# Positive with probability = 0.525
# Correct
# Negative with probability = 0.297
# Correct
# Negative with probability = 0.118
# Negative with probability = 0.260
# Correct
# Negative with probability = 0.358
# Correct
# Positive with probability = 0.740
# Positive with probability = 0.934
# Correct
# Negative with probability = 0.077
# Correct
# Negative with probability = 0.374
# Positive with probability = 0.769
# Correct
# Negative with probability = 0.423
# Correct
# Positive with probability = 0.908
# Negative with probability = 0.079
# Positive with probability = 0.605
# Positive with probability = 0.568
# Correct
# Negative with probability = 0.443
# Negative with probability = 0.223
# Negative with probability = 0.223
# Negative with probability = 0.382
# Correct
# Positive with probability = 0.951
# Correct
# Positive with probability = 0.524
# Correct
# Negative with probability = 0.332
# Correct
# Positive with probability = 0.749
# Correct
# Negative with probability = 0.414
# Negative with probability = 0.173
# Negative with probability = 0.213
# Positive with probability = 0.757
# Correct
# Negative with probability = 0.498
# Positive with probability = 0.774
# Correct
# Negative with probability = 0.263
# Negative with probability = 0.362
# Correct
# Positive with probability = 0.865
# Negative with probability = 0.495
# Negative with probability = 0.365
# Correct
# Positive with probability = 0.543
# Correct
# Negative with probability = 0.318
# Correct
# Positive with probability = 0.509
# Correct
# Positive with probability = 0.725
# Negative with probability = 0.086
# Correct
# Negative with probability = 0.201
# Correct
# Negative with probability = 0.149
# Negative with probability = 0.156
# Negative with probability = 0.105
# Correct
# Negative with probability = 0.493
# Positive with probability = 0.548
# Correct
# Negative with probability = 0.097
# Negative with probability = 0.412
# Positive with probability = 0.870
# Correct
# Negative with probability = 0.215
# Correct
# Negative with probability = 0.187
# Correct
# Negative with probability = 0.339
# Positive with probability = 0.954
# Correct
# Positive with probability = 0.942
# Negative with probability = 0.083
# Correct
# Positive with probability = 0.758
# Positive with probability = 0.635
# Negative with probability = 0.346
# Correct
# Negative with probability = 0.146
# Correct
# Negative with probability = 0.480
# Correct
# Negative with probability = 0.202
# Correct
# Negative with probability = 0.152
# Negative with probability = 0.357
# Positive with probability = 0.508
# Negative with probability = 0.229
# Negative with probability = 0.178
# Correct
# Positive with probability = 0.926
# Correct
# Positive with probability = 0.597
# Positive with probability = 0.571
# Correct
# Positive with probability = 0.900
# Positive with probability = 0.970
# Positive with probability = 0.701
# Correct
# Negative with probability = 0.034
# Correct
# Positive with probability = 0.901
# Positive with probability = 0.863
# Correct
# Negative with probability = 0.285
# Correct
# Negative with probability = 0.437
# Correct
# Negative with probability = 0.240
# Correct
# Negative with probability = 0.042
# Positive with probability = 0.898
# Negative with probability = 0.106
# Positive with probability = 0.855
# Correct
# Positive with probability = 0.883
# Negative with probability = 0.133
# Correct
# Positive with probability = 0.885
# Negative with probability = 0.139
# Positive with probability = 0.539
# Correct
# Negative with probability = 0.120
# Correct
# Positive with probability = 0.957
# Correct
# Negative with probability = 0.255
# Correct
# Negative with probability = 0.486
# Correct
# Positive with probability = 0.948
# Correct
# Negative with probability = 0.101
# Negative with probability = 0.103
# Correct
# Positive with probability = 0.662
# Correct
# Positive with probability = 0.544
# Positive with probability = 0.833
# Correct
# Negative with probability = 0.374
# Correct
# Negative with probability = 0.107
# Correct
# Positive with probability = 0.678
# Negative with probability = 0.081
# Positive with probability = 0.531
# Correct
# Negative with probability = 0.426
# Correct
# Positive with probability = 0.581
# Positive with probability = 0.721
# Positive with probability = 0.776
# Correct
# Negative with probability = 0.107
# Positive with probability = 0.508
# Positive with probability = 0.573
# Correct
# Positive with probability = 0.787
# Negative with probability = 0.101
# Correct
# Positive with probability = 0.533
# Negative with probability = 0.301
# Negative with probability = 0.458
# Correct
# Positive with probability = 0.811
# Correct
# Negative with probability = 0.296
# Correct
# Negative with probability = 0.194
# Negative with probability = 0.302
# Correct
# Positive with probability = 0.834
# Correct
# Negative with probability = 0.307
# Correct
# Negative with probability = 0.192
# Positive with probability = 0.926
# Correct
# Positive with probability = 0.513
# Negative with probability = 0.155
# Correct
# Positive with probability = 0.879
# Correct
# Positive with probability = 0.960
# Correct
# Negative with probability = 0.132
# Correct
# Negative with probability = 0.325
# Correct
# Positive with probability = 0.969
# Correct
# Negative with probability = 0.397
# Correct
# Negative with probability = 0.483
# Negative with probability = 0.434
# Positive with probability = 0.617
# Negative with probability = 0.136
# Negative with probability = 0.227
# Correct
# Negative with probability = 0.141
# Correct
# Positive with probability = 0.722
# Correct
# Positive with probability = 0.962
# Correct
# Positive with probability = 0.758
# Positive with probability = 0.839
# Correct
# Positive with probability = 0.923
# Correct
# Positive with probability = 0.598
# Negative with probability = 0.412
# Positive with probability = 0.816
# Correct
# Positive with probability = 0.583
# Positive with probability = 0.971
# Correct
# Negative with probability = 0.358
# Negative with probability = 0.154
# Correct
# Negative with probability = 0.158
# Correct
# Negative with probability = 0.194
# Correct
# Positive with probability = 0.648
# Correct
# Negative with probability = 0.414
# Correct
# Negative with probability = 0.430
# Negative with probability = 0.257
# Correct
# Positive with probability = 0.940
# Positive with probability = 0.753
# Correct
# Positive with probability = 0.956
# Correct
# Negative with probability = 0.438
# Negative with probability = 0.317
# Correct
# Positive with probability = 0.910
# Negative with probability = 0.494
# Correct
# Positive with probability = 0.938
# Correct
# Negative with probability = 0.235
# Correct
# Negative with probability = 0.425
# Correct
# Positive with probability = 0.567
# Correct
# Negative with probability = 0.061
# Correct
# Negative with probability = 0.133
# Positive with probability = 0.736
# Positive with probability = 0.897
# Correct
# Positive with probability = 0.852
# Correct
# Positive with probability = 0.774
# Correct
# Negative with probability = 0.412
# Correct
# Positive with probability = 0.896
# Positive with probability = 0.902
# Negative with probability = 0.371
# Negative with probability = 0.271
# Correct
# Positive with probability = 0.621
# Correct
# Negative with probability = 0.240
# Correct
# Positive with probability = 0.939
# Correct
# Positive with probability = 0.534
# Correct
# Positive with probability = 0.515
# Correct
# Positive with probability = 0.901
# Negative with probability = 0.192
# Correct
# Negative with probability = 0.200
# Positive with probability = 0.611
# Correct
# Negative with probability = 0.257
# Correct
# Negative with probability = 0.315
# Positive with probability = 0.795
# Correct
# Negative with probability = 0.252
# Correct
# Negative with probability = 0.263
# Correct
# Negative with probability = 0.283
# Correct
# Positive with probability = 0.752
# Positive with probability = 0.717
# Correct
# Positive with probability = 0.592
# Positive with probability = 0.951
# Correct
# Negative with probability = 0.292
# Positive with probability = 0.857
# Correct
# Negative with probability = 0.219
# Negative with probability = 0.219
# Positive with probability = 0.574
# Correct
# Negative with probability = 0.398
# Correct
# Positive with probability = 0.708
# Positive with probability = 0.659
# Correct
# Positive with probability = 0.832
# Negative with probability = 0.172
# Correct
# Positive with probability = 0.608
# Correct
# Negative with probability = 0.281
# Negative with probability = 0.407
# Positive with probability = 0.768
# Negative with probability = 0.195
# Correct
# Positive with probability = 0.629
# Correct
# Positive with probability = 0.540
# Positive with probability = 0.681
# Negative with probability = 0.351
# Correct
# Negative with probability = 0.185
# Positive with probability = 0.815
# Correct
# Positive with probability = 0.630
# Correct
# Negative with probability = 0.332
# Correct
# Negative with probability = 0.481
# Correct
# Positive with probability = 0.832
# Correct
# Negative with probability = 0.477
# Correct
# Negative with probability = 0.332
# Positive with probability = 0.521
# Positive with probability = 0.548
# Negative with probability = 0.496
# Positive with probability = 0.657
# Positive with probability = 0.798
# Correct
# Positive with probability = 0.897
# Positive with probability = 0.522
# Correct
# Negative with probability = 0.130
# Correct
# Negative with probability = 0.215
# Correct
# Positive with probability = 0.784
# Correct
# Positive with probability = 0.537
# Correct
# Positive with probability = 0.548
# Correct
# Negative with probability = 0.359
# Positive with probability = 0.731
# Correct
# Positive with probability = 0.966
# Correct
# Negative with probability = 0.237
# Correct
# Negative with probability = 0.141
# Correct
# Negative with probability = 0.339
# Correct
# Negative with probability = 0.354
# Correct
# Negative with probability = 0.109
# Correct
# Positive with probability = 0.960
# Correct
# Positive with probability = 0.954
# Negative with probability = 0.303
# Correct
# Negative with probability = 0.326
# Correct
# Negative with probability = 0.215
# Correct
# Negative with probability = 0.407
# Positive with probability = 0.675
# Negative with probability = 0.212
# Negative with probability = 0.344
# Correct
# Negative with probability = 0.490
# Correct
# Negative with probability = 0.299
# Negative with probability = 0.279
# Correct
# Negative with probability = 0.089
# Negative with probability = 0.098
# Correct
# Negative with probability = 0.349
# Correct
# Negative with probability = 0.185
# Correct
# Positive with probability = 0.518
# Negative with probability = 0.415
# Positive with probability = 0.924
# Negative with probability = 0.232
# Correct
# Positive with probability = 0.704
# Negative with probability = 0.289
# Accuracy: 0.5783333333333334

# %% [markdown]
# I only test the network with 600 of the test data entries, as my computer cannot handle any more than that. The network has ~90% accuracy on the training dataset yet only ~58% accuracy on the test dataset, which leads me to believe that overfitting may be occurring. I reduced the number of epochs but it still seems like that is occurring.
